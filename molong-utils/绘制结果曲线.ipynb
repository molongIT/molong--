# %%
import matplotlib.pyplot as plt

# 数据
keys = ['srcPred', 'srcAfter10', 'srcAfter20', 'srcAfter40', 'srcAfter80', 'srcAfter160']
dice_scores = [0.8476257429539209, 0.8486311368350962, 0.850970006299577, 
               0.8561876810044898, 0.8612024716382777, 0.8626855779427359]

cldice_scores = [223.59596116946818, 224.53258119409725, 225.5249404085014, 
                 226.9803051436009, 227.61721091420227, 225.87026937380196]

betti_scores = [0.93359375, 0.703125, 0.5390625, 
                0.37109375, 0.28515625, 0.2109375]

# 创建三个子图
fig, axs = plt.subplots(3, 1, figsize=(10, 18))

# 绘制 Dice Score 曲线
axs[0].plot(keys, dice_scores, marker='o', linestyle='-', color='b')
axs[0].set_title('Dice Score')
axs[0].set_xlabel('Stage')
axs[0].set_ylabel('Dice Score')
axs[0].grid(True)

# 绘制 clDice Score 曲线
axs[1].plot(keys, cldice_scores, marker='o', linestyle='-', color='r')
axs[1].set_title('clDice Score')
axs[1].set_xlabel('Stage')
axs[1].set_ylabel('clDice Score')
axs[1].grid(True)

# 绘制 0-dim Betti 曲线
axs[2].plot(keys, betti_scores, marker='o', linestyle='-', color='g')
axs[2].set_title('0-dim Betti')
axs[2].set_xlabel('Stage')
axs[2].set_ylabel('0-dim Betti')
axs[2].grid(True)

# 调整子图布局
plt.tight_layout()

# 显示图表
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# 原始和处理后平均指标数据
mean_metrics0 = {
    'dice': 0.13359174433882884,
    'cldice': 32.35295204717242,
    '0betti': 1.0958333333333337,
    'accuracy': 0.8571102557885805
}

mean_metricsAfter = {
    'dice': 0.7994224477586108,
    'cldice': 200.72380469311113,
    '0betti': 0.7124999999999999,
    'accuracy': 0.9670732816098921
}

# 绘制四个曲线图
metrics_names = ['dice', 'cldice', '0betti', 'accuracy']

fig, axs = plt.subplots(4, 1, figsize=(10, 20))

# 绘制 Dice 曲线
axs[0].plot(['原始', '处理后'], [mean_metrics0['dice'], mean_metricsAfter['dice']], marker='o', linestyle='-', color='b')
axs[0].set_title('Dice Score')
axs[0].set_xlabel('Stage')
axs[0].set_ylabel('Dice Score')
axs[0].grid(True)

# 绘制 clDice 曲线
axs[1].plot(['原始', '处理后'], [mean_metrics0['cldice'], mean_metricsAfter['cldice']], marker='o', linestyle='-', color='r')
axs[1].set_title('clDice Score')
axs[1].set_xlabel('Stage')
axs[1].set_ylabel('clDice Score')
axs[1].grid(True)

# 绘制 0-dim Betti 曲线
axs[2].plot(['原始', '处理后'], [mean_metrics0['0betti'], mean_metricsAfter['0betti']], marker='o', linestyle='-', color='g')
axs[2].set_title('0-dim Betti')
axs[2].set_xlabel('Stage')
axs[2].set_ylabel('0-dim Betti')
axs[2].grid(True)

# 绘制 Accuracy 曲线
axs[3].plot(['原始', '处理后'], [mean_metrics0['accuracy'], mean_metricsAfter['accuracy']], marker='o', linestyle='-', color='m')
axs[3].set_title('Accuracy')
axs[3].set_xlabel('Stage')
axs[3].set_ylabel('Accuracy')
axs[3].grid(True)

# 调整子图布局
plt.tight_layout()

# 显示图表
plt.show()
# Out:
# /tmp/ipykernel_702912/2867746.py:53: UserWarning: Glyph 21407 (\N{CJK UNIFIED IDEOGRAPH-539F}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_702912/2867746.py:53: UserWarning: Glyph 22987 (\N{CJK UNIFIED IDEOGRAPH-59CB}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_702912/2867746.py:53: UserWarning: Glyph 22788 (\N{CJK UNIFIED IDEOGRAPH-5904}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_702912/2867746.py:53: UserWarning: Glyph 29702 (\N{CJK UNIFIED IDEOGRAPH-7406}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_702912/2867746.py:53: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   plt.tight_layout()
